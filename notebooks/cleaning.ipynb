# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '3.0.3'

# %%
data = pd.read_csv("credit_card_fraud_10k.csv")

# %%
data.head(10)
# Out:
#    transaction_id  amount  transaction_hour merchant_category  \
# 0               1   84.47                22       Electronics
# 1               2  541.82                 3            Travel
# 2               3  237.01                17           Grocery
# 3               4  164.33                 4           Grocery
# 4               5   30.53                15              Food
# 5               6   30.53                13          Clothing
# 6               7   10.77                18            Travel
# 7               8  362.02                13       Electronics
# 8               9  165.43                 8           Grocery
# 9              10  221.63                 5           Grocery
#
#    foreign_transaction  location_mismatch  device_trust_score  \
# 0                    0                  0                  66
# 1                    1                  0                  87
# 2                    0                  0                  49
# ...

# %%
data.columns
# Out:
# Index(['transaction_id', 'amount', 'transaction_hour', 'merchant_category',
#        'foreign_transaction', 'location_mismatch', 'device_trust_score',
#        'velocity_last_24h', 'cardholder_age', 'is_fraud'],
#       dtype='str')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   transaction_id       10000 non-null  int64
#  1   amount               10000 non-null  float64
#  2   transaction_hour     10000 non-null  int64
#  3   merchant_category    10000 non-null  str
#  4   foreign_transaction  10000 non-null  int64
#  5   location_mismatch    10000 non-null  int64
#  6   device_trust_score   10000 non-null  int64
#  7   velocity_last_24h    10000 non-null  int64
#  8   cardholder_age       10000 non-null  int64
#  9   is_fraud             10000 non-null  int64
# dtypes: float64(1), int64(8), str(1)
# memory usage: 781.4 KB

# %%
data.shape
# Out:
# (10000, 10)

# %%
"""Deleting redundant columns.
Renaming the columns.
Dropping duplicates.
Remove the NaN values from the dataset
Cleaning individual columns.
Check for some more Trnasformations"""
# Out:
# 'Deleting redundant columns.\nRenaming the columns.\nDropping duplicates.\nRemove the NaN values from the dataset\nCleaning individual columns.\nCheck for some more Trnasformations'

# %%
data.columns
# Out:
# Index(['transaction_id', 'amount', 'transaction_hour', 'merchant_category',
#        'foreign_transaction', 'location_mismatch', 'device_trust_score',
#        'velocity_last_24h', 'cardholder_age', 'is_fraud'],
#       dtype='str')

# %%
columns_to_keep = ['transaction_hour', 'merchant_category']
columns_to_drop = ['transaction_id', 'amount','cardholder_age', 'is_fraud']

# %%
data.shape
# Out:
# (10000, 2)

# %%
len(columns_to_keep)
# Out:
# 2

# %%
len(columns_to_drop)
# Out:
# 4

# %% [markdown]
# # 1st Way - Filtering Data

# %%
columns_to_keep
# Out:
# ['transaction_hour', 'merchant_category']

# %%
modify_data = data[columns_to_keep]

# %%
modify_data
# Out:
#       transaction_hour merchant_category
# 0                   22       Electronics
# 1                    3            Travel
# 2                   17           Grocery
# 3                    4           Grocery
# 4                   15              Food
# ...                ...               ...
# 9995                22              Food
# 9996                 5          Clothing
# 9997                21       Electronics
# 9998                 2       Electronics
# 9999                 2          Clothing
#
# [10000 rows x 2 columns]

# %% [markdown]
# # 2nd way,dropping the columns

# %%
columns_to_drop
# Out:
# ['transaction_id', 'amount', 'cardholder_age', 'is_fraud']

# %%
import pandas as pd

data = pd.read_csv("credit_card_fraud_10k.csv")

# %%
columns_to_drop = ['transaction_id', 'amount', 'cardholder_age', 'is_fraud']

data = data.drop(columns=columns_to_drop, errors='ignore')

# %%
"""Deleting redundant columns.
Renaming the columns.
Dropping duplicates.
Remove the NaN values from the dataset
Cleaning individual columns.
Check for some more Transformations"""
# Out:
# 'Deleting redundant columns.\nRenaming the columns.\nDropping duplicates.\nRemove the NaN values from the dataset\nCleaning individual columns.\nCheck for some more Transformations'

# %%
data
# Out:
#       transaction_hour merchant_category
# 0                   22       Electronics
# 1                    3            Travel
# 2                   17           Grocery
# 3                    4           Grocery
# 4                   15              Food
# ...                ...               ...
# 9995                22              Food
# 9996                 5          Clothing
# 9997                21       Electronics
# 9998                 2       Electronics
# 9999                 2          Clothing
#
# [10000 rows x 2 columns]

# %% [markdown]
# # removing 1 by 1

# %%
data.rename(columns ={"transaction_hour":"transaction_hour1"})
# Out:
#       transaction_hour1 merchant_category
# 0                    22       Electronics
# 1                     3            Travel
# 2                    17           Grocery
# 3                     4           Grocery
# 4                    15              Food
# ...                 ...               ...
# 9995                 22              Food
# 9996                  5          Clothing
# 9997                 21       Electronics
# 9998                  2       Electronics
# 9999                  2          Clothing
#
# [10000 rows x 2 columns]

# %%
data.columns
# Out:
# Index(['transaction_hour', 'merchant_category'], dtype='str')

# %%
data.columns[0].capitalize()
# Out:
# 'Transaction_hour'

# %%
for i in data.columns:
    print(i.capitalize())
# Out:
# Transaction_hour
# Merchant_category

# %%
new_column_names = []
for i in data.columns:
     new_column_names.append(i.capitalize())

# %%
new_column_names
# Out:
# ['Transaction_hour', 'Merchant_category']

# %%
data.columns = new_column_names

# %%
data.columns
# Out:
# Index(['Transaction_hour', 'Merchant_category'], dtype='str')

# %%
"""Deleting redundant columns.
Renaming the columns. -
Dropping duplicates.
Remove the NaN values from the dataset
Cleaning individual columns.
Check for some more Transformations"""
# Out:
# 'Deleting redundant columns.\nRenaming the columns. -\nDropping duplicates.\nRemove the NaN values from the dataset\nCleaning individual columns.\nCheck for some more Transformations'

# %%
data.duplicated().sum()
# Out:
# np.int64(9880)

# %%
data.duplicated().value_counts()
# Out:
# True     9880
# False     120
# Name: count, dtype: int64

# %%
data.duplicated().tail(15)
# Out:
# 9985    True
# 9986    True
# 9987    True
# 9988    True
# 9989    True
# 9990    True
# 9991    True
# 9992    True
# 9993    True
# 9994    True
# 9995    True
# 9996    True
# 9997    True
# 9998    True
# 9999    True
# dtype: bool

# %%
data.drop_duplicates(inplace = True)

# %%
data.isna().sum()
# Out:
# Transaction_hour     0
# Merchant_category    0
# dtype: int64

# %%
data.dropna(inplace = True)

# %%
data.isna().sum()
# Out:
# Transaction_hour     0
# Merchant_category    0
# dtype: int64

# %%
data.reset_index(inplace=True)

# %%
data.drop(columns="index",inplace=True)

# %%
data
# Out:
#      Transaction_hour Merchant_category
# 0                  22       Electronics
# 1                   3            Travel
# 2                  17           Grocery
# 3                   4           Grocery
# 4                  15              Food
# ..                ...               ...
# 115                 8            Travel
# 116                 0            Travel
# 117                10            Travel
# 118                 2       Electronics
# 119                 2           Grocery
#
# [120 rows x 2 columns]

# %%
"""Deleting redundant columns.
Renaming the columns. -
Dropping duplicates.
Remove the NaN values from the dataset
Cleaning individual columns.
Check for some more Transformations"""

# %%
if "Rate" in data.columns:
    print(data["Rate"][14])
else:
    print("Column not found")
# Out:
# Column not found

# %%
data
# Out:
#      Transaction_hour Merchant_category
# 0                  22       Electronics
# 1                   3            Travel
# 2                  17           Grocery
# 3                   4           Grocery
# 4                  15              Food
# ..                ...               ...
# 115                 8            Travel
# 116                 0            Travel
# 117                10            Travel
# 118                 2       Electronics
# 119                 2           Grocery
#
# [120 rows x 2 columns]

# %%
"""Deleting redundant columns.
Renaming the columns. -
Dropping duplicates.
Remove the NaN values from the dataset
Cleaning individual columns.
Check for some more Transformations"""
# Out:
# 'Deleting redundant columns.\nRenaming the columns. -\nDropping duplicates.\nRemove the NaN values from the dataset\nCleaning individual columns.\nCheck for some more Transformations'

# %%
data
# Out:
#      Transaction_hour Merchant_category
# 0                  22       Electronics
# 1                   3            Travel
# 2                  17           Grocery
# 3                   4           Grocery
# 4                  15              Food
# ..                ...               ...
# 115                 8            Travel
# 116                 0            Travel
# 117                10            Travel
# 118                 2       Electronics
# 119                 2           Grocery
#
# [120 rows x 2 columns]

# %%
data["Merchant_category"]
# Out:
# 0      Electronics
# 1           Travel
# 2          Grocery
# 3          Grocery
# 4             Food
#           ...
# 115         Travel
# 116         Travel
# 117         Travel
# 118    Electronics
# 119        Grocery
# Name: Merchant_category, Length: 120, dtype: str

# %%
data["Merchant_category"].apply(lambda x: 1 if x == "Yes" else 0)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 115    0
# 116    0
# 117    0
# 118    0
# 119    0
# Name: Merchant_category, Length: 120, dtype: int64

# %%
data
# Out:
#      Transaction_hour Merchant_category
# 0                  22       Electronics
# 1                   3            Travel
# 2                  17           Grocery
# 3                   4           Grocery
# 4                  15              Food
# ..                ...               ...
# 115                 8            Travel
# 116                 0            Travel
# 117                10            Travel
# 118                 2       Electronics
# 119                 2           Grocery
#
# [120 rows x 2 columns]

# %%
data.to_csv("Cleaned_csv_file.csv")

# %%
pd.read_csv("Cleaned_csv_file.csv")
# Out:
#      Unnamed: 0  Transaction_hour Merchant_category
# 0             0                22       Electronics
# 1             1                 3            Travel
# 2             2                17           Grocery
# 3             3                 4           Grocery
# 4             4                15              Food
# ..          ...               ...               ...
# 115         115                 8            Travel
# 116         116                 0            Travel
# 117         117                10            Travel
# 118         118                 2       Electronics
# 119         119                 2           Grocery
#
# [120 rows x 3 columns]

# %%
data.to_csv("Cleaned_csv_file_no_index.csv",index = False)

# %%
pd.read_csv("Cleaned_csv_file_no_index.csv")
# Out:
#      Transaction_hour Merchant_category
# 0                  22       Electronics
# 1                   3            Travel
# 2                  17           Grocery
# 3                   4           Grocery
# 4                  15              Food
# ..                ...               ...
# 115                 8            Travel
# 116                 0            Travel
# 117                10            Travel
# 118                 2       Electronics
# 119                 2           Grocery
#
# [120 rows x 2 columns]
